# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pickle



import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# ###### Data Dictionary:
#
# - W – Win: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work (also related: winning percentage)
# - R – Runs scored: number of times a player crosses home plate
# - AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
# - H – Hit: reaching base because of a batted, fair ball without error by the defense
# - 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error
# - 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
# - HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
# - BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base.
# - K – Strike out (also abbreviated SO): number of times that a third strike is taken or swung at and missed, or bunted foul. Catcher must catch the third strike or batter may attempt to run to first base.
# - SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense
# - RA – Run average: number of runs allowed times nine divided by innings pitched
# - ER – Earned run: number of runs that did not occur as a result of errors or passed balls
# - ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
# - CG – Complete game: number of games where player was the only pitcher for their team
# - SHO – Shutout: number of complete games pitched with no runs allowed
# - SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings
# - E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result

# %%
data.shape
# Out:
# (30, 17)

# %%
data.rename(columns = {'2B': 'Double', '3B':'Triple'}, inplace = True)

data.head()
# Out:
#     W    R    AB     H  Double  Triple   HR   BB    SO   SB   RA   ER   ERA  \
# 0  95  724  5575  1497     300      42  139  383   973  104  641  601  3.73
# 1  83  696  5467  1349     277      44  156  439  1264   70  700  653  4.07
# 2  81  669  5439  1395     303      29  141  533  1157   86  640  584  3.67
# 3  76  622  5533  1381     260      27  136  404  1231   68  701  643  3.98
# 4  74  689  5605  1515     289      49  151  455  1259   83  803  746  4.64
#
#    CG  SHO  SV    E
# 0   2    8  56   88
# 1   2   12  45   86
# 2  11   10  38   79
# 3   7    9  37  101
# 4   7   12  35   86

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   Double  30 non-null     int64
#  5   Triple  30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
data.isnull().sum()
# Out:
# W         0
# R         0
# AB        0
# H         0
# Double    0
# Triple    0
# HR        0
# BB        0
# SO        0
# SB        0
# RA        0
# ER        0
# ERA       0
# CG        0
# SHO       0
# SV        0
# E         0
# dtype: int64

# %%
data.describe()
# Out:
#                 W           R           AB            H      Double  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#           Triple          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
data_corr = data.corr().abs()

plt.figure(figsize = (22,16))
sns.heatmap(data_corr, annot = True, annot_kws={'size':12})
plt.show()

# %% [markdown]
# Observations:
# - There seems to be strong correlation between RA, ER and ERA variables. We will check the same using VIF.
# - R, ER and ERA having strong relation with Target variable W, we will check the same using Hypothesis Testing and Intercept.
# - AB and H, are having correlation values as 0.74, all other variables are having very less correlation values.

# %% [markdown]
# ## Univariate Analysis

# %%
sns.distplot(data.R)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(data.AB)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(data.H)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(data.Double)
# Out:
# <AxesSubplot:xlabel='Double', ylabel='Density'>

# %%
sns.distplot(data.Triple)
# Out:
# <AxesSubplot:xlabel='Triple', ylabel='Density'>

# %%
sns.distplot(data.HR)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(data.BB)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(data.SO)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(data.SB)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(data.RA)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(data.ER)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(data.ERA)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(data.CG)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(data.SHO)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(data.SV)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(data.E)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# There seems to be some skewness in the data, we will check for the same.

# %% [markdown]
# # Bivariate Analysis

# %%
sns.regplot(x='R', y='W', data=data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.regplot(x='ER', y='W', data=data)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.regplot(x='ERA', y='W', data=data)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %% [markdown]
# Both ER and ERA variables are negativly related with the Target variable W, whereas R(Run) is having positive linear relation with Target Variable W.

# %%
sns.regplot(x='R', y='ER', data=data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='ER'>

# %%
sns.regplot(x='R', y='ERA', data=data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='ERA'>

# %%
sns.regplot(x='ER', y='ERA', data=data)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='ERA'>

# %% [markdown]
# It can be clearly seen that R is very weakly realted with ER and ERA, but ER and ERA has a very strongly relation amongst them.

# %%
sns.regplot(x='H', y='W', data=data)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.regplot(x='AB', y='W', data=data)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.regplot(x='H', y='AB', data=data)
# Out:
# <AxesSubplot:xlabel='H', ylabel='AB'>

# %% [markdown]
# H and AB, both are very weakly related with Win, whereas they are strongly related with each other.

# %% [markdown]
# # Checking Skewness

# %%
x = data.drop(columns = ['W'])
y = data['W']

# %%
x.skew().sort_values(ascending = False)
# Out:
# R         1.200786
# E         0.890132
# CG        0.736845
# H         0.670254
# SV        0.657524
# SHO       0.565790
# HR        0.516441
# SB        0.479893
# AB        0.183437
# BB        0.158498
# Triple    0.129502
# ER        0.058710
# ERA       0.053331
# RA        0.045734
# SO       -0.156065
# Double   -0.230650
# dtype: float64

# %% [markdown]
# There seems to be skewness present in the data, ranging from -0.23 to +1.20.
#
# Therefore, we will use power_transformation function to remove skewness.

# %%
from sklearn.preprocessing import power_transform
x_new = power_transform(x)

# %%
pd.DataFrame(x_new, columns = x.columns).skew().sort_values(ascending = False)
# Out:
# AB        0.090410
# E         0.063909
# SO        0.041170
# SHO       0.006560
# ERA       0.001746
# SV        0.000836
# H         0.000000
# HR       -0.000065
# ER       -0.001940
# BB       -0.007760
# RA       -0.008082
# SB       -0.010455
# Double   -0.035315
# R        -0.055006
# CG       -0.059785
# Triple   -0.072933
# dtype: float64

# %% [markdown]
# Now, we can see the skewness is removed.

# %%
x = pd.DataFrame(x_new, columns = x.columns)

x.head()
# Out:
#           R        AB             H    Double    Triple        HR        BB  \
# 0  0.728218  0.858727  4.996004e-16  1.477685  1.033103 -0.764626 -1.610915
# 1  0.261212 -0.701451 -3.053113e-16  0.084269  1.203320 -0.158581 -0.502749
# 2 -0.244821 -1.126097  0.000000e+00  1.670782 -0.160270 -0.689676  1.128294
# 3 -1.285129  0.267369 -8.326673e-17 -0.848600 -0.360521 -0.879049 -1.181207
# 4  0.135622  1.267645  5.828671e-16  0.792183  1.616444 -0.329850 -0.206771
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.569896  0.939708 -0.660331 -0.497425 -0.500893 -0.359844 -0.789579
# 1  0.134913 -0.539693  0.175465  0.257974  0.261806 -0.359844  0.251775
# 2 -0.901254  0.211956 -0.674621 -0.746906 -0.636459  1.993513 -0.245393
# 3 -0.189628 -0.642564  0.189512  0.113575  0.060804  1.220103 -0.510759
# 4  0.085459  0.079629  1.603228  1.582654  1.520959  1.220103  0.251775
#
#          SV         E
# 0  1.546378 -0.334953
# 1  0.360444 -0.532211
# 2 -0.607594 -1.342331
# 3 -0.764453  0.678524
# 4 -1.095010 -0.532211

# %%
plt.figure(figsize = (20,20))
plotnumber = 1

for column in x:
    if plotnumber <= 16:
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(x[column])
        plt.xlabel(column, fontsize = 20)
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# After removal of skewness from the data, it looks perfectly normalized.

# %%
plt.figure(figsize=(20,25))
fignumber = 1

for column in x:
    if fignumber<= 16:
        ax = plt.subplot(4,4,fignumber)
        sns.regplot(x[column],y)
        
    fignumber +=1
plt.show()

# %% [markdown]
# Observations:
# - The R(number of runs), HR (home runs), 2B(doubles), SV(Saves), SHO(Shutouts), and BB(Walks) are highly positively linearly correlated.
#
# - SB(Stolen Bases), RA(Runs Allowed), ER(Earned Runs), ERA(Earned Runs Average) are highly negative linearly correlated.
#
# - The remaining features have less to no linear correlation with no of Wins.

# %% [markdown]
# # Checking Outliers

# %%
x.iloc[:,:].boxplot(figsize = (20,8))
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# It seems that all the data points are within the range of 3Z.
#
# Let's check using Z-Score

# %%
from scipy.stats import zscore
(np.abs(zscore(x))<3).all()
# Out:
# R         True
# AB        True
# H         True
# Double    True
# Triple    True
# HR        True
# BB        True
# SO        True
# SB        True
# RA        True
# ER        True
# ERA       True
# CG        True
# SHO       True
# SV        True
# E         True
# dtype: bool

# %% [markdown]
# There is no Outlier present in the DataSet.

# %% [markdown]
# ##### Checking Multicollinearity using VIF

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()

vif['vif'] = [variance_inflation_factor(x_scaled, i) for i in range (x_scaled.shape[1])]

vif['features'] = x.columns


# Lets check the values 
vif
# Out:
#             vif features
# 0     10.105172        R
# 1     13.097976       AB
# 2      7.691412        H
# 3      3.771955   Double
# 4      3.294036   Triple
# 5     11.029874       HR
# 6      3.503707       BB
# 7      2.822950       SO
# 8      2.238197       SB
# 9    222.525272       RA
# 10  1966.569612       ER
# 11  1346.157088      ERA
# 12     2.506851       CG
# 13     3.343211      SHO
# 14     5.110873       SV
# 15     2.059791        E

# %% [markdown]
# AS the value of VIF is very high that means, There is a strong correlation between features. Therefore removing the feature with heighest VIF values and then will see the variation in VIF.

# %%
x_new = x.drop(columns = ['ER'], axis=1)

x_new.head()
# Out:
#           R        AB             H    Double    Triple        HR        BB  \
# 0  0.728218  0.858727  4.996004e-16  1.477685  1.033103 -0.764626 -1.610915
# 1  0.261212 -0.701451 -3.053113e-16  0.084269  1.203320 -0.158581 -0.502749
# 2 -0.244821 -1.126097  0.000000e+00  1.670782 -0.160270 -0.689676  1.128294
# 3 -1.285129  0.267369 -8.326673e-17 -0.848600 -0.360521 -0.879049 -1.181207
# 4  0.135622  1.267645  5.828671e-16  0.792183  1.616444 -0.329850 -0.206771
#
#          SO        SB        RA       ERA        CG       SHO        SV  \
# 0 -2.569896  0.939708 -0.660331 -0.500893 -0.359844 -0.789579  1.546378
# 1  0.134913 -0.539693  0.175465  0.261806 -0.359844  0.251775  0.360444
# 2 -0.901254  0.211956 -0.674621 -0.636459  1.993513 -0.245393 -0.607594
# 3 -0.189628 -0.642564  0.189512  0.060804  1.220103 -0.510759 -0.764453
# 4  0.085459  0.079629  1.603228  1.520959  1.220103  0.251775 -1.095010
#
#           E
# 0 -0.334953
# 1 -0.532211
# 2 -1.342331
# 3  0.678524
# 4 -0.532211

# %%
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x_new)

# %%
vif = pd.DataFrame()

vif['vif'] = [variance_inflation_factor(x_scaled, i) for i in range (x_scaled.shape[1])]

vif['features'] = x_new.columns


# Lets check the values 
vif
# Out:
#            vif features
# 0     8.426743        R
# 1     5.269672       AB
# 2     7.572972        H
# 3     3.536450   Double
# 4     3.249997   Triple
# 5     7.930197       HR
# 6     3.501556       BB
# 7     2.558839       SO
# 8     1.968825       SB
# 9   126.635153       RA
# 10  126.607370      ERA
# 11    2.345903       CG
# 12    3.037239      SHO
# 13    2.448338       SV
# 14    2.012400        E

# %% [markdown]
# As it can be easily seen that there is a significant drop in VIF value, but still it is high, therefore removing the other feature with High vif value i.e. ER.

# %%
x_new = x_new.drop(columns = ['ERA'], axis=1)

x_new.head()
# Out:
#           R        AB             H    Double    Triple        HR        BB  \
# 0  0.728218  0.858727  4.996004e-16  1.477685  1.033103 -0.764626 -1.610915
# 1  0.261212 -0.701451 -3.053113e-16  0.084269  1.203320 -0.158581 -0.502749
# 2 -0.244821 -1.126097  0.000000e+00  1.670782 -0.160270 -0.689676  1.128294
# 3 -1.285129  0.267369 -8.326673e-17 -0.848600 -0.360521 -0.879049 -1.181207
# 4  0.135622  1.267645  5.828671e-16  0.792183  1.616444 -0.329850 -0.206771
#
#          SO        SB        RA        CG       SHO        SV         E
# 0 -2.569896  0.939708 -0.660331 -0.359844 -0.789579  1.546378 -0.334953
# 1  0.134913 -0.539693  0.175465 -0.359844  0.251775  0.360444 -0.532211
# 2 -0.901254  0.211956 -0.674621  1.993513 -0.245393 -0.607594 -1.342331
# 3 -0.189628 -0.642564  0.189512  1.220103 -0.510759 -0.764453  0.678524
# 4  0.085459  0.079629  1.603228  1.220103  0.251775 -1.095010 -0.532211

# %%
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x_new)

# %%
vif = pd.DataFrame()

vif['vif'] = [variance_inflation_factor(x_scaled, i) for i in range (x_scaled.shape[1])]

vif['features'] = x_new.columns


# Lets check the values 
vif
# Out:
#          vif features
# 0   8.320764        R
# 1   3.923048       AB
# 2   6.519210        H
# 3   3.256274   Double
# 4   2.963971   Triple
# 5   6.973421       HR
# 6   3.122691       BB
# 7   2.264705       SO
# 8   1.967539       SB
# 9   4.636032       RA
# 10  2.252306       CG
# 11  3.033479      SHO
# 12  2.288205       SV
# 13  1.900294        E

# %% [markdown]
# VIF values are reduced compared to earlier, and it ranges below 10 therefore, proceeding ahead with dataset.

# %% [markdown]
# # ML Models

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
max_r2_score = 0
maxRS = 0

for i in range(1,1000):
    x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.25, random_state = i)
    reg = LinearRegression()
    reg.fit(x_train, y_train)
    y_pred = reg.predict(x_test)
    r2score = r2_score(y_test,y_pred)
    print('r2_score', r2score*100,'%', 'random_state', i)
    
    if r2score > max_r2_score:
        max_r2_score = r2score
        maxRS = i
        print('r2_score', max_r2_score*100,'%', 'random_state', i)
# Out:
# r2_score 44.3953623709087 % random_state 1
# r2_score 44.3953623709087 % random_state 1
# r2_score -0.25351952476386774 % random_state 2
# r2_score 68.71035010128432 % random_state 3
# r2_score 68.71035010128432 % random_state 3
# r2_score 65.99907090426301 % random_state 4
# r2_score 75.17543680289339 % random_state 5
# r2_score 75.17543680289339 % random_state 5
# r2_score 59.190595689964 % random_state 6
# r2_score 79.74913601518041 % random_state 7
# r2_score 79.74913601518041 % random_state 7
# r2_score 59.07643099286959 % random_state 8
# r2_score 66.40334448876207 % random_state 9
# r2_score 38.4496364111486 % random_state 10
# r2_score 39.20135877322167 % random_state 11
# r2_score 61.54878542788238 % random_state 12
# r2_score 72.3759188028725 % random_state 13
# r2_score 61.46092965172847 % random_state 14
# r2_score 45.24272092641313 % random_state 15
# r2_score 58.70306178333695 % random_state 16
# r2_score 0.2903588601352203 % random_state 17
# r2_score -25.704394949510135 % random_state 18
# r2_score 86.30831903721766 % random_state 19
# r2_score 86.30831903721766 % random_state 19
# r2_score 56.93895329736418 % random_state 20
# r2_score 73.47604098921612 % random_state 21
# r2_score 55.29580585617183 % random_state 22
# r2_score 61.619698984651386 % random_state 23
# r2_score -314.15327609363663 % random_state 24
# r2_score -36.79881115706276 % random_state 25
# r2_score -28.690621945498652 % random_state 26
# r2_score 47.78846773349732 % random_state 27
# r2_score 57.379005877471954 % random_state 28
# r2_score 77.6807616167183 % random_state 29
# r2_score 50.69607733592751 % random_state 30
# r2_score 18.595756190971723 % random_state 31
# r2_score 48.331515664895605 % random_state 32
# r2_score 71.33450715042542 % random_state 33
# r2_score 79.98725517109848 % random_state 34
# r2_score 59.59436969154791 % random_state 35
# r2_score 39.62385015487324 % random_state 36
# r2_score 43.61730509207187 % random_state 37
# r2_score 20.11336932790805 % random_state 38
# r2_score 85.34900053242383 % random_state 39
# r2_score 58.05566282505692 % random_state 40
# r2_score 49.74962833600113 % random_state 41
# r2_score 81.82228499331401 % random_state 42
# r2_score 26.96340129102025 % random_state 43
# r2_score 63.39877596929339 % random_state 44
# r2_score 75.37068260127838 % random_state 45
# r2_score 43.79257929305055 % random_state 46
# r2_score 60.507594064097916 % random_state 47
# r2_score 76.51750549264861 % random_state 48
# r2_score 58.31983552028296 % random_state 49
# r2_score 68.69949182585717 % random_state 50
# r2_score 5.069237942861415 % random_state 51
# r2_score 51.92097022376366 % random_state 52
# r2_score 66.43898831735666 % random_state 53
# r2_score 60.51593769758845 % random_state 54
# r2_score 60.75033948666828 % random_state 55
# r2_score 63.75882115050145 % random_state 56
# r2_score 27.307974250880385 % random_state 57
# r2_score 30.9659330240051 % random_state 58
# r2_score 42.51989634910627 % random_state 59
# r2_score 2.237885322920208 % random_state 60
# r2_score -88.57670171491428 % random_state 61
# r2_score -99.97548613133958 % random_state 62
# r2_score 65.33025506367952 % random_state 63
# r2_score 65.48599415139553 % random_state 64
# r2_score 67.36008550081063 % random_state 65
# r2_score 9.958226023151528 % random_state 66
# r2_score 20.44806923107233 % random_state 67
# r2_score 36.11878076886524 % random_state 68
# r2_score 83.49970873525496 % random_state 69
# r2_score 84.15915714135018 % random_state 70
# r2_score 62.132811504408835 % random_state 71
# r2_score 45.173640413065684 % random_state 72
# r2_score 54.09302861672507 % random_state 73
# r2_score -62.423615290015455 % random_state 74
# r2_score 38.16878274945703 % random_state 75
# r2_score 3.5041480426711846 % random_state 76
# r2_score 68.70295803687274 % random_state 77
# r2_score 62.711577024929156 % random_state 78
# r2_score 25.01929359653462 % random_state 79
# r2_score 62.207192508124834 % random_state 80
# r2_score -45.51197243787279 % random_state 81
# r2_score 69.91755708877764 % random_state 82
# r2_score 71.5889634503034 % random_state 83
# r2_score 51.643320332707646 % random_state 84
# r2_score 58.82114755824078 % random_state 85
# r2_score 55.539299492546334 % random_state 86
# r2_score 24.963783052767663 % random_state 87
# r2_score -11.308074342884922 % random_state 88
# r2_score 75.25338207996857 % random_state 89
# r2_score 69.13251756079292 % random_state 90
# r2_score 39.37971278798966 % random_state 91
# r2_score 56.64754997493722 % random_state 92
# r2_score 72.0716399994077 % random_state 93
# r2_score 19.854089831804355 % random_state 94
# r2_score 51.94097083814867 % random_state 95
# r2_score 51.26774145207123 % random_state 96
# r2_score 37.160321060140646 % random_state 97
# r2_score 60.555124620825374 % random_state 98
# r2_score 76.51909172726889 % random_state 99
# r2_score -29.631122813529686 % random_state 100
# r2_score 49.36820020893198 % random_state 101
# r2_score 1.9131739595590114 % random_state 102
# r2_score 85.44754755111819 % random_state 103
# r2_score 68.19666897287698 % random_state 104
# r2_score 45.79539137325143 % random_state 105
# r2_score 27.333523807910034 % random_state 106
# r2_score 10.38430531824812 % random_state 107
# r2_score 55.9667719125508 % random_state 108
# r2_score -10.764918680223069 % random_state 109
# r2_score 56.42092880043674 % random_state 110
# r2_score 66.63941854628412 % random_state 111
# r2_score 64.52480195083142 % random_state 112
# r2_score 56.34329136021164 % random_state 113
# r2_score 77.34042196728825 % random_state 114
# r2_score 57.87762328179539 % random_state 115
# r2_score 72.05675116627512 % random_state 116
# r2_score -31.804413320470104 % random_state 117
# r2_score 54.78509436856691 % random_state 118
# r2_score 71.09130034046795 % random_state 119
# r2_score 23.70408597911633 % random_state 120
# r2_score 82.2813253022745 % random_state 121
# r2_score 51.18439936492163 % random_state 122
# r2_score 6.299605974676037 % random_state 123
# r2_score 18.973698256193007 % random_state 124
# r2_score 61.90654586398344 % random_state 125
# r2_score 42.5355444701923 % random_state 126
# r2_score 61.773012891272884 % random_state 127
# r2_score 17.04616812952452 % random_state 128
# r2_score 88.44578869257455 % random_state 129
# r2_score 88.44578869257455 % random_state 129
# r2_score 4.958734722572644 % random_state 130
# r2_score 51.8068568058704 % random_state 131
# r2_score 55.68400300228162 % random_state 132
# r2_score 33.61982850674311 % random_state 133
# r2_score 61.95087668178866 % random_state 134
# r2_score 2.019455926029967 % random_state 135
# r2_score 54.602857256690605 % random_state 136
# r2_score 81.5004494186052 % random_state 137
# r2_score 26.91657513012773 % random_state 138
# r2_score 30.053721985416214 % random_state 139
# r2_score 36.10992018236103 % random_state 140
# r2_score 54.13514078262509 % random_state 141
# r2_score 76.95250701952858 % random_state 142
# r2_score 56.346889177469436 % random_state 143
# r2_score 74.65374490774738 % random_state 144
# r2_score 43.055334120411146 % random_state 145
# r2_score 56.48491071379584 % random_state 146
# r2_score 7.7874520630013215 % random_state 147
# r2_score 79.23855830956985 % random_state 148
# r2_score 76.44340987116583 % random_state 149
# r2_score -17.184073006037927 % random_state 150
# r2_score -2.341290536785978 % random_state 151
# r2_score -1.3684074803550939 % random_state 152
# r2_score 70.21333817823054 % random_state 153
# r2_score 12.828705701353972 % random_state 154
# r2_score 27.04203720765449 % random_state 155
# r2_score 3.1703618714443604 % random_state 156
# r2_score 54.19966414620704 % random_state 157
# r2_score -5.366078783997841 % random_state 158
# r2_score 69.35638879509555 % random_state 159
# r2_score 53.237567853662156 % random_state 160
# r2_score 81.31644666242033 % random_state 161
# r2_score 84.26614389368729 % random_state 162
# r2_score 84.04193692528445 % random_state 163
# r2_score 14.061003429515228 % random_state 164
# r2_score 87.35562036201225 % random_state 165
# r2_score 17.824393888062517 % random_state 166
# r2_score 87.73668295775136 % random_state 167
# r2_score 21.733765574537124 % random_state 168
# r2_score 27.29965015635971 % random_state 169
# r2_score -17.728652273195912 % random_state 170
# r2_score 56.44796801979935 % random_state 171
# r2_score 9.007651476430256 % random_state 172
# r2_score -53.50704634633039 % random_state 173
# r2_score -3.630155083047115 % random_state 174
# r2_score 13.318727705586763 % random_state 175
# r2_score 43.2177932391124 % random_state 176
# r2_score 18.969303337008135 % random_state 177
# r2_score 54.62819595949158 % random_state 178
# r2_score 49.01795474853502 % random_state 179
# r2_score 81.07222150571111 % random_state 180
# r2_score 53.30970378817149 % random_state 181
# r2_score 54.96717498601911 % random_state 182
# r2_score -19.096739535053906 % random_state 183
# r2_score 3.702242362397612 % random_state 184
# r2_score 67.14633018467123 % random_state 185
# r2_score -14.080798494258762 % random_state 186
# r2_score 44.35588412169182 % random_state 187
# r2_score 41.75166251600479 % random_state 188
# r2_score 73.8379469175964 % random_state 189
# r2_score 47.37696604145864 % random_state 190
# r2_score 85.84821844538921 % random_state 191
# r2_score -74.34922147432536 % random_state 192
# r2_score 76.51047439192179 % random_state 193
# r2_score -62.119185921297834 % random_state 194
# r2_score 64.69884643454134 % random_state 195
# r2_score 56.58835671939549 % random_state 196
# r2_score 61.10536236493087 % random_state 197
# r2_score 60.143525608600456 % random_state 198
# r2_score 25.688786373543127 % random_state 199
# r2_score 83.80249747478999 % random_state 200
# r2_score 6.954128626150147 % random_state 201
# r2_score 38.50371152561015 % random_state 202
# r2_score -129.6884351227772 % random_state 203
# r2_score -76.35746723934433 % random_state 204
# r2_score -181.88037166304034 % random_state 205
# r2_score 43.2300365898043 % random_state 206
# r2_score 73.02730759608671 % random_state 207
# r2_score 60.35571476551158 % random_state 208
# r2_score 43.83124530664052 % random_state 209
# r2_score 38.983564645036274 % random_state 210
# r2_score 27.203511003678283 % random_state 211
# r2_score 52.37002165043104 % random_state 212
# r2_score 55.96141674165269 % random_state 213
# r2_score 61.26128624067715 % random_state 214
# r2_score 64.98591876696076 % random_state 215
# r2_score 24.98991569311095 % random_state 216
# r2_score 62.00686503915145 % random_state 217
# r2_score 77.38756037192913 % random_state 218
# r2_score 60.32893590090708 % random_state 219
# r2_score 28.93800135440825 % random_state 220
# r2_score 72.99474523299637 % random_state 221
# r2_score 79.61041190229429 % random_state 222
# r2_score 72.49267961193449 % random_state 223
# r2_score 38.55730997357766 % random_state 224
# r2_score 76.99917105536811 % random_state 225
# r2_score 68.43767714008436 % random_state 226
# r2_score 59.07724929326796 % random_state 227
# r2_score 1.3589805754020134 % random_state 228
# r2_score 43.04441034241263 % random_state 229
# r2_score 46.15845468032054 % random_state 230
# r2_score 71.01792441010637 % random_state 231
# r2_score 44.48582492137224 % random_state 232
# r2_score 30.783662592497407 % random_state 233
# r2_score 73.74990806560294 % random_state 234
# r2_score -71.20098117859963 % random_state 235
# r2_score 69.49007804926435 % random_state 236
# r2_score 66.79213550886783 % random_state 237
# r2_score 5.721535354103469 % random_state 238
# r2_score 72.2223152551899 % random_state 239
# r2_score 54.14401497824504 % random_state 240
# r2_score 46.46911593095334 % random_state 241
# r2_score 62.47652078879862 % random_state 242
# r2_score 71.80959437651093 % random_state 243
# r2_score 42.75911422681957 % random_state 244
# r2_score -43.65875471474858 % random_state 245
# r2_score 72.4774971660629 % random_state 246
# r2_score 57.74343018718678 % random_state 247
# r2_score 41.99572930450336 % random_state 248
# r2_score 93.59148336010668 % random_state 249
# r2_score 93.59148336010668 % random_state 249
# r2_score 59.05277284821921 % random_state 250
# r2_score 74.41313972568584 % random_state 251
# r2_score 66.28525256062726 % random_state 252
# r2_score 26.238680394189164 % random_state 253
# r2_score 58.416539462747444 % random_state 254
# r2_score -25.509992587187867 % random_state 255
# r2_score 41.98925815103872 % random_state 256
# r2_score 22.958864198209984 % random_state 257
# r2_score 54.19821542987254 % random_state 258
# r2_score 45.12200365590978 % random_state 259
# r2_score 21.473566250668263 % random_state 260
# r2_score 15.607107927074592 % random_state 261
# r2_score 1.5362304986533681 % random_state 262
# r2_score 85.51225438497724 % random_state 263
# r2_score 82.82528003038793 % random_state 264
# r2_score 20.17676854523748 % random_state 265
# r2_score 41.36442733153971 % random_state 266
# r2_score 67.02989022215273 % random_state 267
# r2_score 67.15513598191612 % random_state 268
# r2_score 92.55125618731232 % random_state 269
# r2_score 80.78539905683616 % random_state 270
# r2_score 51.6602271469292 % random_state 271
# r2_score 79.78969225554229 % random_state 272
# r2_score 31.667421059310364 % random_state 273
# r2_score 83.11238980749363 % random_state 274
# r2_score 72.4862346959235 % random_state 275
# r2_score 75.66915688450604 % random_state 276
# r2_score 69.06996591650321 % random_state 277
# r2_score 46.49946703021243 % random_state 278
# r2_score -37.06236734870034 % random_state 279
# r2_score 74.94881201825925 % random_state 280
# r2_score -6.935250622951261 % random_state 281
# r2_score 92.44363689523071 % random_state 282
# r2_score 68.47928176958618 % random_state 283
# r2_score 46.03996196248905 % random_state 284
# r2_score 62.83032167295488 % random_state 285
# r2_score 17.175379959332016 % random_state 286
# r2_score 70.52721416255719 % random_state 287
# r2_score 85.81548167155722 % random_state 288
# r2_score 65.07590676241223 % random_state 289
# r2_score 64.63346083279036 % random_state 290
# r2_score 42.941629569265636 % random_state 291
# r2_score 62.508945523131246 % random_state 292
# r2_score 67.5647349662636 % random_state 293
# r2_score 57.11052442022403 % random_state 294
# r2_score -262.0323061777671 % random_state 295
# r2_score 91.59386816039387 % random_state 296
# r2_score -4.753367943836051 % random_state 297
# r2_score 36.85059319442841 % random_state 298
# r2_score 74.05864219128364 % random_state 299
# r2_score 65.3180318104295 % random_state 300
# r2_score 74.94760302813388 % random_state 301
# r2_score 67.45424720061781 % random_state 302
# r2_score 64.72917607806022 % random_state 303
# r2_score 73.93880074935602 % random_state 304
# r2_score -19.758134911045854 % random_state 305
# r2_score 32.034985936927185 % random_state 306
# r2_score 48.14605670545538 % random_state 307
# r2_score 24.663462693433036 % random_state 308
# r2_score 8.585569201652598 % random_state 309
# r2_score 93.91682454109035 % random_state 310
# r2_score 93.91682454109035 % random_state 310
# r2_score 64.96164666386663 % random_state 311
# r2_score 37.34934651014922 % random_state 312
# r2_score 63.421566291191176 % random_state 313
# r2_score 57.99859859233412 % random_state 314
# r2_score 49.544992659509255 % random_state 315
# r2_score 28.78695841441007 % random_state 316
# r2_score 53.976560539374006 % random_state 317
# r2_score 30.001234488281657 % random_state 318
# r2_score 44.534239161331 % random_state 319
# r2_score 47.09903764774977 % random_state 320
# r2_score 54.76858497502797 % random_state 321
# r2_score 51.9438695682622 % random_state 322
# r2_score 36.155442501866474 % random_state 323
# r2_score 69.21533405479585 % random_state 324
# r2_score 63.5950840514351 % random_state 325
# r2_score -43.36616836824185 % random_state 326
# r2_score 61.249784387135044 % random_state 327
# r2_score 25.056818767268407 % random_state 328
# r2_score 40.62222728728327 % random_state 329
# r2_score 4.552117943301193 % random_state 330
# r2_score -93.96945806920142 % random_state 331
# r2_score 40.17709573525431 % random_state 332
# r2_score 39.64356543283879 % random_state 333
# r2_score 63.16608469024301 % random_state 334
# r2_score 60.43443078384796 % random_state 335
# r2_score 57.02085807568602 % random_state 336
# r2_score -78.13345014955355 % random_state 337
# r2_score -310.0334564036956 % random_state 338
# r2_score 74.7561194124104 % random_state 339
# r2_score 39.1149821876446 % random_state 340
# r2_score 44.61887183543078 % random_state 341
# r2_score 10.162219483340007 % random_state 342
# r2_score 57.332169784590334 % random_state 343
# r2_score 67.675946171111 % random_state 344
# r2_score 34.21457039047888 % random_state 345
# r2_score 50.21455450532031 % random_state 346
# r2_score 87.40728772167482 % random_state 347
# r2_score 62.28196660872701 % random_state 348
# r2_score -31.64301199692401 % random_state 349
# r2_score 67.64522286517692 % random_state 350
# r2_score 53.23800861355228 % random_state 351
# r2_score 61.67311888144472 % random_state 352
# r2_score 84.86302974391178 % random_state 353
# r2_score 74.97847938382758 % random_state 354
# r2_score 41.97623909077429 % random_state 355
# r2_score 55.6147374835156 % random_state 356
# r2_score 15.972680994841436 % random_state 357
# r2_score 7.28620198260761 % random_state 358
# r2_score 44.940535480542664 % random_state 359
# r2_score 28.532988669477156 % random_state 360
# r2_score 16.24437214641481 % random_state 361
# r2_score 75.66174111756546 % random_state 362
# r2_score 12.824677330452626 % random_state 363
# r2_score 22.451767722497806 % random_state 364
# r2_score 37.61980026738979 % random_state 365
# r2_score 51.73092040084857 % random_state 366
# r2_score 62.128359114492596 % random_state 367
# r2_score 63.294424263746926 % random_state 368
# r2_score 51.472575631122 % random_state 369
# r2_score 72.6405358854566 % random_state 370
# r2_score -9.109696132422474 % random_state 371
# r2_score -140.7884399991584 % random_state 372
# r2_score 81.25322618275217 % random_state 373
# r2_score 20.59069148406747 % random_state 374
# r2_score 66.9697084991256 % random_state 375
# r2_score 24.756140193432763 % random_state 376
# r2_score 73.52202821124892 % random_state 377
# r2_score -15.628174438002219 % random_state 378
# r2_score 75.3316756716687 % random_state 379
# r2_score 72.8706189415157 % random_state 380
# r2_score 48.426326628145354 % random_state 381
# r2_score 52.44724431474286 % random_state 382
# r2_score 43.65647547526943 % random_state 383
# r2_score 96.5159003835996 % random_state 384
# r2_score 96.5159003835996 % random_state 384
# r2_score 74.11818113546276 % random_state 385
# r2_score -61.19784513246627 % random_state 386
# r2_score 37.45992007410476 % random_state 387
# r2_score 47.78969468631136 % random_state 388
# r2_score 63.98839807083151 % random_state 389
# r2_score 59.037798219421425 % random_state 390
# r2_score -186.13648028109603 % random_state 391
# r2_score 84.5541961946578 % random_state 392
# r2_score 75.52036132804935 % random_state 393
# r2_score 64.92636776770387 % random_state 394
# r2_score 66.19071365248269 % random_state 395
# r2_score 46.89904891973858 % random_state 396
# r2_score 59.390002154946586 % random_state 397
# r2_score 64.96155999605742 % random_state 398
# r2_score 84.17214994884341 % random_state 399
# r2_score 73.9727887583891 % random_state 400
# r2_score -39.98270476020684 % random_state 401
# r2_score 44.14165418405383 % random_state 402
# r2_score -95.52377092778434 % random_state 403
# r2_score 31.106598494438476 % random_state 404
# r2_score 23.744302877022484 % random_state 405
# r2_score 70.2340413439505 % random_state 406
# r2_score 46.84322681498322 % random_state 407
# r2_score 90.5360507723147 % random_state 408
# r2_score 48.44501703806312 % random_state 409
# r2_score 66.77306466063008 % random_state 410
# r2_score 81.05959896796814 % random_state 411
# r2_score -2.2693401635438315 % random_state 412
# r2_score 51.659386969793665 % random_state 413
# r2_score 36.91944126569094 % random_state 414
# r2_score 63.00850273772689 % random_state 415
# r2_score 51.110786779612006 % random_state 416
# r2_score 76.25700989779853 % random_state 417
# r2_score 36.63143360462998 % random_state 418
# r2_score 28.827827430147668 % random_state 419
# r2_score 28.00936906961553 % random_state 420
# r2_score 26.97309791293081 % random_state 421
# r2_score 38.397703611208925 % random_state 422
# r2_score 74.461712365681 % random_state 423
# r2_score 65.40980921794336 % random_state 424
# r2_score 66.51740896454885 % random_state 425
# r2_score 48.14289117568872 % random_state 426
# r2_score 39.677128265887475 % random_state 427
# r2_score 59.120905858045305 % random_state 428
# r2_score 82.6099501683635 % random_state 429
# r2_score 66.94986042302784 % random_state 430
# r2_score -84.59645179589208 % random_state 431
# r2_score -27.337784174577216 % random_state 432
# r2_score 79.89822067683406 % random_state 433
# r2_score 58.78244381957971 % random_state 434
# r2_score 76.90323428557986 % random_state 435
# r2_score 12.162026513061052 % random_state 436
# r2_score 45.609675092168686 % random_state 437
# r2_score -55.05218088276889 % random_state 438
# r2_score 38.476999415736515 % random_state 439
# r2_score -141.0096167158581 % random_state 440
# r2_score 13.363341397648277 % random_state 441
# r2_score 71.94763591547299 % random_state 442
# r2_score 41.1861476187131 % random_state 443
# r2_score 52.376210699173164 % random_state 444
# r2_score 75.12225473900537 % random_state 445
# r2_score 84.05976321004883 % random_state 446
# r2_score 56.38234253164156 % random_state 447
# r2_score 81.47793745665258 % random_state 448
# r2_score -0.44645423181788324 % random_state 449
# r2_score 78.60747884416912 % random_state 450
# r2_score 80.98124116550149 % random_state 451
# r2_score -27.772625199003677 % random_state 452
# r2_score 82.7690331740367 % random_state 453
# r2_score 81.51851180321242 % random_state 454
# r2_score 27.099092652756028 % random_state 455
# r2_score 84.36890585814186 % random_state 456
# r2_score 56.547742565641435 % random_state 457
# r2_score 50.00702515452943 % random_state 458
# r2_score 77.47936608178966 % random_state 459
# r2_score 4.483820659818072 % random_state 460
# r2_score -315.68243630035084 % random_state 461
# r2_score 2.9103987745184634 % random_state 462
# r2_score -95.86948263723103 % random_state 463
# r2_score 44.92490635579759 % random_state 464
# r2_score 22.413143133260725 % random_state 465
# r2_score 39.846273029975656 % random_state 466
# r2_score 78.1153273337394 % random_state 467
# r2_score 33.97561748241048 % random_state 468
# r2_score 66.7327296694717 % random_state 469
# r2_score 57.42162419646873 % random_state 470
# r2_score 23.76458911937842 % random_state 471
# r2_score 32.45267085882978 % random_state 472
# r2_score 56.94205733068787 % random_state 473
# r2_score 66.105161572044 % random_state 474
# r2_score 30.750417485284377 % random_state 475
# r2_score 34.06191500376388 % random_state 476
# r2_score 45.07037030630114 % random_state 477
# r2_score 66.45037982820845 % random_state 478
# r2_score 78.95676379853566 % random_state 479
# r2_score 67.43642139308668 % random_state 480
# r2_score 32.52245579063822 % random_state 481
# r2_score 33.59460958925426 % random_state 482
# r2_score -19.311277610282907 % random_state 483
# r2_score 32.683546616843905 % random_state 484
# r2_score -39.405270825261795 % random_state 485
# r2_score 44.49278502540709 % random_state 486
# r2_score 85.52425631188483 % random_state 487
# r2_score 68.56262273333485 % random_state 488
# r2_score 80.50635988525985 % random_state 489
# r2_score 67.98910005894538 % random_state 490
# r2_score -3.5996652419220343 % random_state 491
# r2_score 72.09298923078393 % random_state 492
# r2_score 56.38632035426618 % random_state 493
# r2_score 61.33066680962125 % random_state 494
# r2_score 77.59733464784422 % random_state 495
# r2_score 62.11092087333452 % random_state 496
# r2_score 37.033516487388184 % random_state 497
# r2_score 82.18839592585113 % random_state 498
# r2_score 37.54849727112959 % random_state 499
# r2_score 66.63284101572336 % random_state 500
# r2_score -57.621729624527205 % random_state 501
# r2_score -3.0500259643948313 % random_state 502
# r2_score 31.664761291688926 % random_state 503
# r2_score 67.7323259674105 % random_state 504
# r2_score 57.81645586746143 % random_state 505
# r2_score 74.79307396044233 % random_state 506
# r2_score 56.170109975326376 % random_state 507
# r2_score -5.0846350018411535 % random_state 508
# r2_score 71.47013290868179 % random_state 509
# r2_score 43.73400254606952 % random_state 510
# r2_score 83.69937167299221 % random_state 511
# r2_score 52.99894433474455 % random_state 512
# r2_score -25.922920553576013 % random_state 513
# r2_score 62.65311832907079 % random_state 514
# r2_score 40.603751511491346 % random_state 515
# r2_score 19.3390544912496 % random_state 516
# r2_score 45.37496388081147 % random_state 517
# r2_score 46.86434264521242 % random_state 518
# r2_score -30.93770624423291 % random_state 519
# r2_score 82.49613476665566 % random_state 520
# r2_score 78.52798708310773 % random_state 521
# r2_score 17.02228977032546 % random_state 522
# r2_score 73.39976810414997 % random_state 523
# r2_score 22.07885541444895 % random_state 524
# r2_score 36.83803025444799 % random_state 525
# r2_score 74.25702877481626 % random_state 526
# r2_score 64.11353586885602 % random_state 527
# r2_score 62.53623268979427 % random_state 528
# r2_score 60.6561028157462 % random_state 529
# r2_score 65.84576405187623 % random_state 530
# r2_score 80.73741628086626 % random_state 531
# r2_score 71.61449184848622 % random_state 532
# r2_score 53.63243260654023 % random_state 533
# r2_score 57.34338502668488 % random_state 534
# r2_score 56.28835462755002 % random_state 535
# r2_score 60.685129740473286 % random_state 536
# r2_score 68.0410492373126 % random_state 537
# r2_score -155.66649025737914 % random_state 538
# r2_score 72.89869877975781 % random_state 539
# r2_score -595.688205758787 % random_state 540
# r2_score 12.446834893780935 % random_state 541
# r2_score 59.71918467183399 % random_state 542
# r2_score 41.56387598301187 % random_state 543
# r2_score -139.35521160242894 % random_state 544
# r2_score 82.84894825984507 % random_state 545
# r2_score 78.82170380670557 % random_state 546
# r2_score 61.46470842831783 % random_state 547
# r2_score 16.005040870446653 % random_state 548
# r2_score 13.031201563537397 % random_state 549
# r2_score -114.55952647259684 % random_state 550
# r2_score 86.04881177587751 % random_state 551
# r2_score -85.35110195034873 % random_state 552
# r2_score 41.85927372367272 % random_state 553
# r2_score -12.755531395506736 % random_state 554
# r2_score 47.74329247020444 % random_state 555
# r2_score 56.176127646298845 % random_state 556
# r2_score 72.07110865677035 % random_state 557
# r2_score 4.841957263546382 % random_state 558
# r2_score 63.99810624333113 % random_state 559
# r2_score 59.428060827978314 % random_state 560
# r2_score 37.30112125150552 % random_state 561
# r2_score -41.11979125598355 % random_state 562
# r2_score 32.75555406335885 % random_state 563
# r2_score 8.068243335979497 % random_state 564
# r2_score 77.06481550978552 % random_state 565
# r2_score -76.75557283867096 % random_state 566
# r2_score 33.439348169210604 % random_state 567
# r2_score 67.04089942872847 % random_state 568
# r2_score 46.89113552209261 % random_state 569
# r2_score 41.62114317066029 % random_state 570
# r2_score 74.81483501708246 % random_state 571
# r2_score 58.63610464622915 % random_state 572
# r2_score 55.0217963552618 % random_state 573
# r2_score 32.69537209482324 % random_state 574
# r2_score -44.032630646702266 % random_state 575
# r2_score -14.058953815000264 % random_state 576
# r2_score -35.56726712042049 % random_state 577
# r2_score 25.20530143436932 % random_state 578
# r2_score 26.192576740357467 % random_state 579
# r2_score 40.5242979251063 % random_state 580
# r2_score 61.92238444893422 % random_state 581
# r2_score 74.59880614589811 % random_state 582
# r2_score 58.84653743140762 % random_state 583
# r2_score -86.82562055502616 % random_state 584
# r2_score -78.29616258690115 % random_state 585
# r2_score 77.03920254448379 % random_state 586
# r2_score 62.180457680413284 % random_state 587
# r2_score -80.94990072371375 % random_state 588
# r2_score 6.8676810059426385 % random_state 589
# r2_score -2.4490597060649266 % random_state 590
# r2_score 54.379940708179 % random_state 591
# r2_score 66.63115097146837 % random_state 592
# r2_score 53.51043476677715 % random_state 593
# r2_score 84.6547175125852 % random_state 594
# r2_score 47.56550368061012 % random_state 595
# r2_score 81.89881725187647 % random_state 596
# r2_score 82.35326455177811 % random_state 597
# r2_score 49.90213540415635 % random_state 598
# r2_score 49.588466308736166 % random_state 599
# r2_score -3.732553915582404 % random_state 600
# r2_score 57.416808879840254 % random_state 601
# r2_score 10.140841770593823 % random_state 602
# r2_score -210.34163239909444 % random_state 603
# r2_score 64.19521266688439 % random_state 604
# r2_score -60.23895491227735 % random_state 605
# r2_score 63.48508552902785 % random_state 606
# r2_score 55.255302439443675 % random_state 607
# r2_score 56.035892175384895 % random_state 608
# r2_score 82.44168106859657 % random_state 609
# r2_score -17.366336229448898 % random_state 610
# r2_score 63.760534681204064 % random_state 611
# r2_score 61.86449864966232 % random_state 612
# r2_score 32.15650671609421 % random_state 613
# r2_score 51.936769047965825 % random_state 614
# r2_score 75.78923202076602 % random_state 615
# r2_score -36.27457736198097 % random_state 616
# r2_score 77.64415924111596 % random_state 617
# r2_score 46.66585368046579 % random_state 618
# r2_score 53.93383143282679 % random_state 619
# r2_score 42.43800721168062 % random_state 620
# r2_score 64.44405334824121 % random_state 621
# r2_score 57.125154911212206 % random_state 622
# r2_score 72.11924456124092 % random_state 623
# r2_score -101.50953887675409 % random_state 624
# r2_score -70.34522664300023 % random_state 625
# r2_score 36.41764881885793 % random_state 626
# r2_score 32.03273911611759 % random_state 627
# r2_score 80.07598804818768 % random_state 628
# r2_score 40.1167888944663 % random_state 629
# r2_score 76.79544910696228 % random_state 630
# r2_score 66.5895768971349 % random_state 631
# r2_score 66.64180303870073 % random_state 632
# r2_score 46.07390774827348 % random_state 633
# r2_score -26.22174668526325 % random_state 634
# r2_score 72.68204131349312 % random_state 635
# r2_score 58.729212235504036 % random_state 636
# r2_score -172.97140750928892 % random_state 637
# r2_score 65.27244116049773 % random_state 638
# r2_score 82.38923472772414 % random_state 639
# r2_score 31.11475623744061 % random_state 640
# r2_score -159.6934200134238 % random_state 641
# r2_score 10.259810114412748 % random_state 642
# r2_score 44.147330989807365 % random_state 643
# r2_score 68.39146002835173 % random_state 644
# r2_score 70.2113128592188 % random_state 645
# r2_score -20.259121767853607 % random_state 646
# r2_score -13.225688709208217 % random_state 647
# r2_score 9.006444631775834 % random_state 648
# r2_score 75.36910393081936 % random_state 649
# r2_score 71.81189028845549 % random_state 650
# r2_score 72.64695519154077 % random_state 651
# r2_score 72.02093511220252 % random_state 652
# r2_score 64.73433340567226 % random_state 653
# r2_score 53.784993013216656 % random_state 654
# r2_score -5.54473691677444 % random_state 655
# r2_score 34.87388642366967 % random_state 656
# r2_score 72.77186399491089 % random_state 657
# r2_score 77.97177183519759 % random_state 658
# r2_score 86.64911514521985 % random_state 659
# r2_score 69.33914219171467 % random_state 660
# r2_score 42.42484665912723 % random_state 661
# r2_score -8.834934935889782 % random_state 662
# r2_score 27.43663642557116 % random_state 663
# r2_score 24.225597002704745 % random_state 664
# r2_score 79.71687959791022 % random_state 665
# r2_score -18.179666567417343 % random_state 666
# r2_score 49.75478992612149 % random_state 667
# r2_score 77.45205426458682 % random_state 668
# r2_score 33.600873445983616 % random_state 669
# r2_score 72.62662863985301 % random_state 670
# r2_score -44.62728157835303 % random_state 671
# r2_score 2.4740129052799653 % random_state 672
# r2_score 72.60340403001506 % random_state 673
# r2_score 39.38336537449225 % random_state 674
# r2_score 49.22182946799653 % random_state 675
# r2_score 53.43316205821262 % random_state 676
# r2_score 31.278812250495104 % random_state 677
# r2_score 77.14780952596259 % random_state 678
# r2_score 86.07529368503671 % random_state 679
# r2_score 61.898299259476296 % random_state 680
# r2_score 22.28493265146666 % random_state 681
# r2_score 2.319526716470355 % random_state 682
# r2_score 65.18436353697456 % random_state 683
# r2_score 73.49579489493632 % random_state 684
# r2_score 68.27212792782531 % random_state 685
# r2_score 54.431892236211766 % random_state 686
# r2_score 16.87095213116131 % random_state 687
# r2_score -62.818133091702855 % random_state 688
# r2_score 53.342586812338965 % random_state 689
# r2_score 58.95781941436364 % random_state 690
# r2_score 47.735899149678005 % random_state 691
# r2_score 23.28729065357723 % random_state 692
# r2_score -3.8567269098608747 % random_state 693
# r2_score -8.467134432771006 % random_state 694
# r2_score 67.50706536566278 % random_state 695
# r2_score 80.80208771905862 % random_state 696
# r2_score 71.33597564663089 % random_state 697
# r2_score 65.87549308936775 % random_state 698
# r2_score -77.89470822643976 % random_state 699
# r2_score 17.06129556442647 % random_state 700
# r2_score 75.25372620710394 % random_state 701
# r2_score 49.991129650715926 % random_state 702
# r2_score 72.63186214861342 % random_state 703
# r2_score 65.761379855746 % random_state 704
# r2_score 66.19311507620725 % random_state 705
# r2_score 56.42439959903505 % random_state 706
# r2_score 72.49411784315497 % random_state 707
# r2_score 37.31895479701133 % random_state 708
# r2_score 50.68276597830017 % random_state 709
# r2_score 41.735642724782366 % random_state 710
# r2_score 83.64133420261707 % random_state 711
# r2_score 63.89521630560855 % random_state 712
# r2_score 45.594789487324505 % random_state 713
# r2_score 55.84524494256602 % random_state 714
# r2_score 43.7508420187685 % random_state 715
# r2_score -323.0443632212972 % random_state 716
# r2_score 42.146294415820186 % random_state 717
# r2_score 70.25497440733908 % random_state 718
# r2_score -33.763892501263015 % random_state 719
# r2_score 35.6630945387178 % random_state 720
# r2_score 55.26504761389941 % random_state 721
# r2_score -66.26294287721353 % random_state 722
# r2_score 60.14773694843111 % random_state 723
# r2_score 70.3184297576596 % random_state 724
# r2_score 65.18296573388322 % random_state 725
# r2_score 45.92707961935199 % random_state 726
# r2_score 85.93603922818333 % random_state 727
# r2_score 59.345042325291594 % random_state 728
# r2_score 62.80427086719236 % random_state 729
# r2_score 68.0025702364535 % random_state 730
# r2_score 57.72714225229 % random_state 731
# r2_score 36.61348949018641 % random_state 732
# r2_score 47.926419453328904 % random_state 733
# r2_score 58.069170031734416 % random_state 734
# r2_score 42.71264772319127 % random_state 735
# r2_score 52.57496601733852 % random_state 736
# r2_score 10.541116594598721 % random_state 737
# r2_score 40.16582655711305 % random_state 738
# r2_score -80.23682358892536 % random_state 739
# r2_score 79.79693780023948 % random_state 740
# r2_score 50.623205308952855 % random_state 741
# r2_score 29.507447085440152 % random_state 742
# r2_score 76.20400743028029 % random_state 743
# r2_score 37.13513153516384 % random_state 744
# r2_score 18.246595754067375 % random_state 745
# r2_score 5.863220691196824 % random_state 746
# r2_score 60.679683211286736 % random_state 747
# r2_score 79.19468859144467 % random_state 748
# r2_score 43.759963263065856 % random_state 749
# r2_score 62.69553859883413 % random_state 750
# r2_score 36.37617466411852 % random_state 751
# r2_score 74.64344784189755 % random_state 752
# r2_score 38.65191711948489 % random_state 753
# r2_score 59.80384900452235 % random_state 754
# r2_score 13.710988623514531 % random_state 755
# r2_score -49.95577202521871 % random_state 756
# r2_score 82.45470335368252 % random_state 757
# r2_score -46.794218376893106 % random_state 758
# r2_score 40.55037847044689 % random_state 759
# r2_score 46.211067006425786 % random_state 760
# r2_score 56.03856582712006 % random_state 761
# r2_score 65.88969377693165 % random_state 762
# r2_score 79.79428815939792 % random_state 763
# r2_score 32.57428616265378 % random_state 764
# r2_score -24.81604203852603 % random_state 765
# r2_score 62.87779016444126 % random_state 766
# r2_score -17.82395306177358 % random_state 767
# r2_score 31.2145373620335 % random_state 768
# r2_score 63.6430982890721 % random_state 769
# r2_score 41.11930395698641 % random_state 770
# r2_score -86.50125929196338 % random_state 771
# r2_score 51.62283140456788 % random_state 772
# r2_score 24.296876257560008 % random_state 773
# r2_score 61.923064329195896 % random_state 774
# r2_score -25.740913481523542 % random_state 775
# r2_score 59.23504289831272 % random_state 776
# r2_score 52.43010631793813 % random_state 777
# r2_score 10.693284835346518 % random_state 778
# r2_score 72.0204099306356 % random_state 779
# r2_score 20.651641983288016 % random_state 780
# r2_score -147.50820112098185 % random_state 781
# r2_score 55.48680538106332 % random_state 782
# r2_score 49.11041719135961 % random_state 783
# r2_score 45.272063359524786 % random_state 784
# r2_score 61.47446637399019 % random_state 785
# r2_score 61.66530525294802 % random_state 786
# r2_score 70.08264495541866 % random_state 787
# r2_score 80.70413386183121 % random_state 788
# r2_score -593.0023361341963 % random_state 789
# r2_score 53.6491485287989 % random_state 790
# r2_score -76.14858637253528 % random_state 791
# r2_score 15.165839853504949 % random_state 792
# r2_score 85.0809972807895 % random_state 793
# r2_score 19.295480728388114 % random_state 794
# r2_score 20.469505443356283 % random_state 795
# r2_score 77.13796179934717 % random_state 796
# r2_score 74.73979975006819 % random_state 797
# r2_score -47.44104853449611 % random_state 798
# r2_score 61.3286311421332 % random_state 799
# r2_score 49.9394638051774 % random_state 800
# r2_score 20.660482524075462 % random_state 801
# r2_score 0.7171430481365815 % random_state 802
# r2_score -49.60654953820593 % random_state 803
# r2_score 59.47733167004095 % random_state 804
# r2_score 67.4746164990003 % random_state 805
# r2_score 76.39495154143118 % random_state 806
# r2_score 70.65864293416534 % random_state 807
# r2_score 10.4995145652365 % random_state 808
# r2_score 41.15271193474229 % random_state 809
# r2_score 86.19441433166133 % random_state 810
# r2_score 68.8139712394533 % random_state 811
# r2_score 44.91776677620357 % random_state 812
# r2_score 49.85727553605936 % random_state 813
# r2_score 1.7772756400389889 % random_state 814
# r2_score 82.28434247852894 % random_state 815
# r2_score 63.977287933761474 % random_state 816
# r2_score 75.54396305968467 % random_state 817
# r2_score 47.51027935033703 % random_state 818
# r2_score 74.30808086559593 % random_state 819
# r2_score 54.090922003905916 % random_state 820
# r2_score -58.189544301465126 % random_state 821
# r2_score -12.898526378558461 % random_state 822
# r2_score 76.36081806270944 % random_state 823
# r2_score 33.152478260359544 % random_state 824
# r2_score 49.09980902726877 % random_state 825
# r2_score 3.2560626734962406 % random_state 826
# r2_score 54.3082991817335 % random_state 827
# r2_score 46.17732792437689 % random_state 828
# r2_score 55.96898552764466 % random_state 829
# r2_score 23.882061244873697 % random_state 830
# r2_score 24.249941511367368 % random_state 831
# r2_score 62.74934754672658 % random_state 832
# r2_score 53.16540361625226 % random_state 833
# r2_score 64.66773200990458 % random_state 834
# r2_score 51.82340235934822 % random_state 835
# r2_score 79.02500128421549 % random_state 836
# r2_score -1.081563331272939 % random_state 837
# r2_score 71.04611849464679 % random_state 838
# r2_score 31.573755829496232 % random_state 839
# r2_score -229.56038516951494 % random_state 840
# r2_score 61.91682706903367 % random_state 841
# r2_score 71.21460426289332 % random_state 842
# r2_score 74.41941897675754 % random_state 843
# r2_score 55.79249457854625 % random_state 844
# r2_score -20.243622380991244 % random_state 845
# r2_score 63.12582559587923 % random_state 846
# r2_score -6.6955047120274 % random_state 847
# r2_score 20.98649008535404 % random_state 848
# r2_score 32.90512141442269 % random_state 849
# r2_score 81.15142647713101 % random_state 850
# r2_score 75.95127343120791 % random_state 851
# r2_score -77.02170809954833 % random_state 852
# r2_score 1.235493132472143 % random_state 853
# r2_score 26.847962818726522 % random_state 854
# r2_score 56.46280855502135 % random_state 855
# r2_score 73.04335961041254 % random_state 856
# r2_score 44.3158008464271 % random_state 857
# r2_score 67.10745132438211 % random_state 858
# r2_score 39.12343079239361 % random_state 859
# r2_score 50.24714931508307 % random_state 860
# r2_score 74.44681847310402 % random_state 861
# r2_score -95.92832465062236 % random_state 862
# r2_score 65.78338125919501 % random_state 863
# r2_score 2.9767557371208397 % random_state 864
# r2_score 59.90233214532796 % random_state 865
# r2_score 44.56180588702105 % random_state 866
# r2_score 16.033654781992503 % random_state 867
# r2_score 58.91647415557999 % random_state 868
# r2_score 41.00059886356655 % random_state 869
# r2_score 60.019843642617566 % random_state 870
# r2_score 71.24449525075191 % random_state 871
# r2_score -3.963262049382732 % random_state 872
# r2_score 36.97959227279915 % random_state 873
# r2_score 50.45327222461475 % random_state 874
# r2_score 53.47170605873912 % random_state 875
# r2_score 25.58893600097538 % random_state 876
# r2_score -79.56725358403918 % random_state 877
# r2_score 54.556620224549015 % random_state 878
# r2_score -43.8773948660325 % random_state 879
# r2_score 77.70477490293406 % random_state 880
# r2_score 27.44813687124765 % random_state 881
# r2_score -120.76592682914801 % random_state 882
# r2_score 16.771508174706927 % random_state 883
# r2_score 40.433980598456785 % random_state 884
# r2_score 65.76210723997723 % random_state 885
# r2_score 64.82904127971686 % random_state 886
# r2_score 49.15118636989012 % random_state 887
# r2_score 45.5790213999916 % random_state 888
# r2_score 85.86763089211247 % random_state 889
# r2_score 51.06594057212854 % random_state 890
# r2_score 31.055598020104046 % random_state 891
# r2_score 57.61162748267849 % random_state 892
# r2_score 82.19757961982924 % random_state 893
# r2_score 50.895479224367214 % random_state 894
# r2_score 59.948926962934415 % random_state 895
# r2_score 50.72565911426956 % random_state 896
# r2_score 24.56212326077737 % random_state 897
# r2_score 50.321609150597666 % random_state 898
# r2_score 55.593704365788845 % random_state 899
# r2_score 66.3900314414112 % random_state 900
# r2_score -20.557691307775205 % random_state 901
# r2_score 27.384040948547028 % random_state 902
# r2_score -9.984643217511735 % random_state 903
# r2_score 66.6284671676352 % random_state 904
# r2_score 56.29180857019287 % random_state 905
# r2_score -10.364570268828665 % random_state 906
# r2_score 65.53998377568539 % random_state 907
# r2_score -6.393940358446359 % random_state 908
# r2_score -14.500916826961486 % random_state 909
# r2_score 30.26828400190843 % random_state 910
# r2_score -38.59908364490352 % random_state 911
# r2_score 64.42460916449473 % random_state 912
# r2_score 58.499296745658214 % random_state 913
# r2_score 56.488922659096595 % random_state 914
# r2_score 64.21645800458509 % random_state 915
# r2_score 25.809703706892506 % random_state 916
# r2_score 2.6972657736542116 % random_state 917
# r2_score 66.79635837756035 % random_state 918
# r2_score 84.66513010909328 % random_state 919
# r2_score -100.31554712332395 % random_state 920
# r2_score 16.386036516798185 % random_state 921
# r2_score 35.81723312678452 % random_state 922
# r2_score 88.09481346298105 % random_state 923
# r2_score 40.795914625357675 % random_state 924
# r2_score 65.99825605093427 % random_state 925
# r2_score 51.542063738439815 % random_state 926
# r2_score 26.398134747671186 % random_state 927
# r2_score 51.00420793033344 % random_state 928
# r2_score 68.76704536335505 % random_state 929
# r2_score -77.85752229831076 % random_state 930
# r2_score -47.96064797328634 % random_state 931
# r2_score 9.244335620472055 % random_state 932
# r2_score -45.3336784848291 % random_state 933
# r2_score 53.894959109593984 % random_state 934
# r2_score 73.98182282349136 % random_state 935
# r2_score -76.3298564707869 % random_state 936
# r2_score 10.352363329304747 % random_state 937
# r2_score 68.91854105173614 % random_state 938
# r2_score 64.20625239763267 % random_state 939
# r2_score 69.80978783462875 % random_state 940
# r2_score 68.2302736195705 % random_state 941
# r2_score -4.235890939461462 % random_state 942
# r2_score 47.73867851286663 % random_state 943
# r2_score 84.84660904505516 % random_state 944
# r2_score -48.824240703866174 % random_state 945
# r2_score -158.34813938580922 % random_state 946
# r2_score 28.670181116610216 % random_state 947
# r2_score 13.18291713676607 % random_state 948
# r2_score 75.96256816967019 % random_state 949
# r2_score 66.5547637354532 % random_state 950
# r2_score 45.13070677768683 % random_state 951
# r2_score 2.0877191283340646 % random_state 952
# r2_score 80.53737073221542 % random_state 953
# r2_score 74.92789901496798 % random_state 954
# r2_score 56.40043372526608 % random_state 955
# r2_score 57.44095267790071 % random_state 956
# r2_score 47.68917990298856 % random_state 957
# r2_score 63.05776629383529 % random_state 958
# r2_score 72.39746007519568 % random_state 959
# r2_score 66.77783286241609 % random_state 960
# r2_score 90.70404462526822 % random_state 961
# r2_score 53.33366296718807 % random_state 962
# r2_score 18.233183663292873 % random_state 963
# r2_score 61.9724025639196 % random_state 964
# r2_score 92.36731296200338 % random_state 965
# r2_score 41.17107993975655 % random_state 966
# r2_score 76.50097382346554 % random_state 967
# r2_score 66.91425288902053 % random_state 968
# r2_score 72.25785470792528 % random_state 969
# r2_score 54.05707290791011 % random_state 970
# r2_score 51.47137757490468 % random_state 971
# r2_score 15.9678427310602 % random_state 972
# r2_score -42.76930696771637 % random_state 973
# r2_score 42.8558866776569 % random_state 974
# r2_score 51.4789409703738 % random_state 975
# r2_score 76.42113637391023 % random_state 976
# r2_score 47.09629089719813 % random_state 977
# r2_score 61.14018591038689 % random_state 978
# r2_score 72.52362595529513 % random_state 979
# r2_score 75.54564322736304 % random_state 980
# r2_score 18.050812236098068 % random_state 981
# r2_score 77.0338362969269 % random_state 982
# r2_score 60.36493318511713 % random_state 983
# r2_score 42.040299563013164 % random_state 984
# r2_score 73.03332125639679 % random_state 985
# r2_score 71.2359052123993 % random_state 986
# r2_score 60.12966430224762 % random_state 987
# r2_score 30.795329074512978 % random_state 988
# r2_score -6.927961162737728 % random_state 989
# r2_score -162.41153290151175 % random_state 990
# r2_score 74.86482951932558 % random_state 991
# r2_score 34.5126235197448 % random_state 992
# r2_score 45.65137192544258 % random_state 993
# r2_score 76.96258209501224 % random_state 994
# r2_score 74.28084140564238 % random_state 995
# r2_score 62.59904768671476 % random_state 996
# r2_score 58.47851149376629 % random_state 997
# r2_score 39.85857152180133 % random_state 998
# r2_score 1.5698819739313086 % random_state 999

# %%
print('Best R2 Score is', max_r2_score, 'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.9651590038359961 on Random_state 384

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.25, random_state = 384)

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
print('Intercept: ', reg.intercept_)
print('Linear Coefficient: ', reg.coef_)
# Out:
# Intercept:  81.1390462631997
# Linear Coefficient:  [ 6.10040008  0.01078089  0.07423176 -0.8653067  -0.68843261 -2.18225359
#  -0.11167058  0.132499   -0.3162509  -5.22509701  1.5426205   0.6699268
#   4.21729363  0.36101641]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('R2 Score: ', r2_score(y_test, y_pred))

print("Mean Absolute Error: ", mean_absolute_error(y_test,y_pred))

print("Mean Squared Error: ", mean_squared_error(y_test,y_pred))

print("Square Root of Mean Square Error: ", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score:  0.9651590038359961
# Mean Absolute Error:  1.4785322098291935
# Mean Squared Error:  2.6038200726942327
# Square Root of Mean Square Error:  1.6136356691317382

# %% [markdown]
# Since there seems to be some relation between independent variable --> R (Run) and Target Variable --> W (Win), therefore applying Hypothesis Testing to identify whether relation between them exists or not.

# %% [markdown]
# # Hypothesis Testing and P-Values
#
# - Ho = there is no relation between Run and Win.
# - Ha = There exists a relation between Run and Win.

# %%
import statsmodels.formula.api as smf

lm = smf.ols(formula = 'W ~ R', data = data).fit()

lm.pvalues
# Out:
# Intercept    0.188745
# R            0.017488
# dtype: float64

# %% [markdown]
# - now since, the p-value is less than alpha value(i.e. 0.05), we reject the null hypothesis.
# - which means, there exists a relation between the Run and Win.

# %%
lm.rsquared
# Out:
# 0.1855460212759742

# %%
lm = LinearRegression()
lm.fit(x_scaled,y)

print('Intercept: ',lm.intercept_)
print('R: ', lm.coef_[0])
print('AB: ', lm.coef_[1])
print('H: ', lm.coef_[2])
print('Double: ', lm.coef_[3])
print('Triple: ', lm.coef_[4])
print('HR: ', lm.coef_[5])
print('BB: ', lm.coef_[6])
print('SO: ', lm.coef_[7])
print('SB: ', lm.coef_[8])
print('RA: ', lm.coef_[9])
print('CG: ', lm.coef_[10])
print('SHO: ', lm.coef_[11])
print('SV: ', lm.coef_[12])
print('E: ', lm.coef_[13])
# Out:
# Intercept:  80.96666666666667
# R:  6.816357943221332
# AB:  -0.2832152700895889
# H:  -0.06440391281680924
# Double:  -1.0558713205256847
# Triple:  -0.57381513359051
# HR:  -2.4430168974673236
# BB:  -0.36091609288986054
# SO:  0.22880701234477657
# SB:  -0.27275947218409313
# RA:  -5.277288585837434
# CG:  1.475964924620485
# SHO:  0.7988826538210435
# SV:  4.322904082937044
# E:  0.5455229200750917

# %%
lm = smf.ols(formula = 'W ~ R + AB + H + Double + Triple + HR + BB + SO + SB +RA + CG + SHO + SV + E', data = data).fit()

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      W   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     15.64
# Date:                Wed, 29 Jun 2022   Prob (F-statistic):           1.82e-06
# Time:                        05:52:37   Log-Likelihood:                -71.258
# No. Observations:                  30   AIC:                             172.5
# Df Residuals:                      15   BIC:                             193.5
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.1071     79.580      0.077      0.940    -163.514     175.728
# R              0.1459      0.038      3.819      0.002       0.064       0.227
# AB             0.0123      0.020      0.605      0.555      -0.031       0.055
# H             -0.0253      0.035     -0.721      0.482      -0.100       0.049
# Double        -0.1054      0.072     -1.458      0.166      -0.260       0.049
# Triple        -0.0398      0.113     -0.351      0.730      -0.281       0.202
# HR            -0.1056      0.059     -1.785      0.094      -0.232       0.020
# BB            -0.0181      0.023     -0.804      0.434      -0.066       0.030
# SO             0.0090      0.010      0.928      0.368      -0.012       0.030
# SB            -0.0120      0.041     -0.296      0.771      -0.099       0.075
# RA            -0.0680      0.021     -3.189      0.006      -0.114      -0.023
# CG             0.8753      0.408      2.145      0.049       0.005       1.745
# SHO            0.2593      0.305      0.850      0.409      -0.391       0.910
# SV             0.6900      0.153      4.506      0.000       0.364       1.016
# E             -0.0089      0.070     -0.126      0.901      -0.159       0.141
# ==============================================================================
# Omnibus:                        7.233   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):                5.532
# Skew:                          -0.843   Prob(JB):                       0.0629
# Kurtosis:                       4.257   Cond. No.                     7.03e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.03e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ##### Observations
#
# 1. P value for R, HR, SV and RA is very low, that means there is a strong relation between these variables and Win.
#
# 2. p value for E is 0.975, which is very high. we can assume that E does not have any significant effect on Win.
#
# 3. R2 and Adj. R2 values are 0.936 and 0.876 respectively, which means the intercept model is very good.

# %%
lm = smf.ols(formula = 'W ~ R+HR+RA+SV', data = data).fit()

lm.rsquared
# Out:
# 0.8971237558371721

# %% [markdown]
# it is clear from R2 values for R, HR, RA and SV have correlation of about 89% with Win.

# %%
lm = smf.ols(formula = 'W ~ AB+E', data = data).fit()

lm.rsquared
# Out:
# 0.011956169381316495

# %% [markdown]
# As observed above, AB and E does dont have any significant effect on win as they have only 1.1% correlation with Win.

# %%
lm = smf.ols(formula = 'W ~  H + Double + Triple + BB + SO + SB + CG + SHO', data = data).fit()

lm.rsquared
# Out:
# 0.5489667438363384

# %% [markdown]
# All other data Points are only 54.8% correlated with Win.

# %%
def print_score(clf, x_train, x_test, y_train, y_test, train=True):
    if train:
        y_pred = clf.predict(x_train)
        
        print("\n====================Train Result======================")
        
        print(f"R2 Score: {r2_score(y_train, y_pred)}")
        
    elif train==False:
        pred = clf.predict(x_test)
        
        print("\n====================Test Result======================")
        
        print(f"R2 Score: {r2_score(y_test, pred)}")
        
        print(f"Root Mean Square Error : {np.sqrt(mean_squared_error(y_test,pred))} ")

# %%
reg = LinearRegression()

# Regression Model training and printing train and test score
reg.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(reg, x_train, x_test, y_train, y_test, train=True)

print_score(reg, x_train, x_test, y_train, y_test, train=False)
# Out:
# ====================Train Result======================
# R2 Score: 0.9140729830503408
#
# ====================Test Result======================
# R2 Score: 0.9651590038359961
# Root Mean Square Error : 1.6136356691317382

# %%
from sklearn.svm import SVC

svc = SVC()

# SVC Model training and printing train and test score
svc.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(svc, x_train, x_test, y_train, y_test, train=True)

print_score(svc, x_train, x_test, y_train, y_test, train=False)
# Out:
# ====================Train Result======================
# R2 Score: 0.7269617120395981
#
# ====================Test Result======================
# R2 Score: -1.4403094292285177
# Root Mean Square Error : 13.504628836069505

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()

# RandomForestClassifier Model training and printing train and test score
rf.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(rf, x_train, x_test, y_train, y_test, train=True)

print_score(rf, x_train, x_test, y_train, y_test, train=False)
# Out:
# ====================Train Result======================
# R2 Score: 0.9269781118066677
#
# ====================Test Result======================
# R2 Score: 0.3688680744302736
# Root Mean Square Error : 6.867841727937535

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()

# XGBoost Regressor Model training and printing train and test score
xgb.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(xgb, x_train, x_test, y_train, y_test, train=True)

print_score(xgb, x_train, x_test, y_train, y_test, train=False)
# Out:
# ====================Train Result======================
# R2 Score: 0.9999999970279948
#
# ====================Test Result======================
# R2 Score: 0.1023958987431196
# Root Mean Square Error : 8.190352953619866

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor()

# KNN Regressor Model training and printing train and test score
knn.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(knn, x_train, x_test, y_train, y_test, train=True)

print_score(knn, x_train, x_test, y_train, y_test, train=False)
# Out:
# ====================Train Result======================
# R2 Score: 0.7717848303974377
#
# ====================Test Result======================
# R2 Score: 0.5061844030942921
# Root Mean Square Error : 6.074948559452995

# %% [markdown]
# ###### Amongst the ML Models, Linear Regression has the best R2 score. Therefore, Let's perform Cross validation(Ridge and Lasso) and Parameter Tuning(Model Regularization using Ridge and Lasso) on Linear Regression Model.

# %% [markdown]
# # Model Regularization Method

# %%
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV

# %%
lasscv = LassoCV(alphas = None, max_iter = 100, normalize = True)
lasscv.fit(x_train, y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
alpha = lasscv.alpha_

alpha
# Out:
# 0.3333529071642167

# %%
lasso_reg = Lasso(alpha)

lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.3333529071642167)

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.8869119518101135

# %% [markdown]
# # Ridge CV

# %%
ridgecv = RidgeCV(alphas = np.arange(0.001,2,0.01), normalize = True)

ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([1.000e-03, 1.100e-02, 2.100e-02, 3.100e-02, 4.100e-02, 5.100e-02,
#        6.100e-02, 7.100e-02, 8.100e-02, 9.100e-02, 1.010e-01, 1.110e-01,
#        1.210e-01, 1.310e-01, 1.410e-01, 1.510e-01, 1.610e-01, 1.710e-01,
#        1.810e-01, 1.910e-01, 2.010e-01, 2.110e-01, 2.210e-01, 2.310e-01,
#        2.410e-01, 2.510e-01, 2.610e-01, 2.710e-01, 2.810e-01, 2.910e-01,
#        3.010e-01, 3.110e-01, 3.210e-0...
#        1.621e+00, 1.631e+00, 1.641e+00, 1.651e+00, 1.661e+00, 1.671e+00,
#        1.681e+00, 1.691e+00, 1.701e+00, 1.711e+00, 1.721e+00, 1.731e+00,
#        1.741e+00, 1.751e+00, 1.761e+00, 1.771e+00, 1.781e+00, 1.791e+00,
#        1.801e+00, 1.811e+00, 1.821e+00, 1.831e+00, 1.841e+00, 1.851e+00,
#        1.861e+00, 1.871e+00, 1.881e+00, 1.891e+00, 1.901e+00, 1.911e+00,
#        1.921e+00, 1.931e+00, 1.941e+00, 1.951e+00, 1.961e+00, 1.971e+00,
#        1.981e+00, 1.991e+00]),
#         normalize=True)

# %%
alpha = ridgecv.alpha_

alpha
# Out:
# 0.3509999999999999

# %%
ridge_model = Ridge(alpha)

ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.3509999999999999)

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.9239642232333585

# %% [markdown]
# ###### Model Saving

# %%
# Saving the Model

import joblib
joblib.dump(reg, "Baseball_Case_Study.pkl")
# Out:
# ['Baseball_Case_Study.pkl']
